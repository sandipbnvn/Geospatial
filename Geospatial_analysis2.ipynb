# %% [markdown]
# Geospatial Analysis:
#
# The objective of this tutorial is to use geospatial analysis to make decisions about opening up new restaurants(or retail stores, bank branches, airports, etc). For our analysis, we use a dataset consisting of Starbucks and McDonalds store coordinates in New York.
#
# Our tutorial consists of the following steps:
#
#
# 1.   Compute the distance of the stores
# 2.   Visualize data on a map
# 3.   Compute number of stores located in a given radius
# 4.   Compute the closest and farthest stores from Empire State Building

# %%
import pandas as pd
import numpy as np
import folium
import geopy.distance

# %%
#Read file containing location details
df = pd.read_csv('https://drive.google.com/uc?id=19JERBe0ndadkMPKDFZ0rTEZqdI50zDfk')
df.head(10)
# Out:
#          lat        lng      store                                 address
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005

# %%
#Merge Columns
df['Coordinate'] = '(' + df['lat'].astype(str) + ', ' + df['lng'].astype(str) + ')'
df.head(10)
# Out:
#          lat        lng      store                                 address  \
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005
#
#                 Coordinate
# 0     (40.711, -74.000878)
# 1  (40.707142, -74.004987)
# 2  (40.708411, -74.007404)
# 3  (40.711644, -74.006667)
# 4  (40.710171, -74.007931)
# 5  (40.706316, -74.006582)
# 6  (40.712208, -74.008192)
# 7  (40.708742, -74.009508)
# 8  (40.706033, -74.008348)
# 9  (40.704817, -74.007231)

# %%
#New York Empire State Building Lat Long (Looking for any approx center point)
NY_coord = (40.748488, -73.985238)

# %% [markdown]
# **1. Compute the distance of the stores**

# %%
#Compute distance of every store from city center
distances_km = []

for row in df.itertuples(index=False):
   distances_km.append(
       geopy.distance.distance(NY_coord, row.Coordinate).km
   )

df['Distance'] = distances_km
df.head(10)
# Out:
#          lat        lng      store                                 address  \
# 0  40.711000 -74.000878  Starbucks        375 Pearl st, New York, NY 10038
# 1  40.707142 -74.004987  Starbucks     135 John Street, New York, NY 10038
# 2  40.708411 -74.007404  Starbucks  100 William Street, New York, NY 10038
# 3  40.711644 -74.006667  Starbucks     38 Park Row, #4, New York, NY 10038
# 4  40.710171 -74.007931  Starbucks   130 Fulton Street, New York, NY 10038
# 5  40.706316 -74.006582  Starbucks      80 Pine Street, New York, NY 10005
# 6  40.712208 -74.008192  Starbucks        233 Broadway, New York, NY 10279
# 7  40.708742 -74.009508  Starbucks   55 Liberty Street, New York, NY 10005
# 8  40.706033 -74.008348  Starbucks          60 Wall St, New York, NY 10005
# 9  40.704817 -74.007231  Starbucks         99 Wall St., New York, NY 10005
#
#                 Coordinate  Distance
# 0     (40.711, -74.000878)  4.367628
# 1  (40.707142, -74.004987)  4.885149
# 2  (40.708411, -74.007404)  4.828401
# 3  (40.711644, -74.006667)  4.474066
# 4  (40.710171, -74.007931)  4.666971
# 5  (40.706316, -74.006582)  5.018288
# 6  (40.712208, -74.008192)  4.471204
# 7  (40.708742, -74.009508)  4.866712
# 8  (40.706033, -74.008348)  5.102829
# 9  (40.704817, -74.007231)  5.193348

# %% [markdown]
# **2.Visualize data on a map**

# %%
#Empire State Building coordinates
m = folium.Map(location=[40.748488, -73.985238], zoom_start= 10)

#Place markers for the stores on the map
for i, row in df.iterrows():
  lat = df.at[i, 'lat']
  lng = df.at[i, 'lng']
  store = df.at[i, 'store']

  if store == 'McDonalds':
    color = 'blue'
  else:
    color = 'green'

  folium.Marker(location=[lat,lng], popup=store, icon= folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c1fb316651803fd61f38d323cefe0d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c1fb316651803fd61f38d323cefe0d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6c1fb316651803fd61f38d323cefe0d6 = L.map(
#                 &quot;map_6c1fb316651803fd61f38d323cefe0d6&quot;,
#                 {
#                     center: [40.748488, -73.985238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e183f2abab3bfa5c61fbdf1ab3720ad = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c1fb316651803fd61f38d323cefe0d6);
#
#
#             var marker_12161f4392e20bf821f0f66846ad670c = L.marker(
#                 [40.711, -74.000878],
#                 {}
#             ).addTo(map_6c1fb316651803fd61f38d323cefe0d6);
#
#
#             var icon_4a5fcc535cd48b590d28558f0a77efbe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_12161f4392e20bf821f0f66846ad670c.setIcon(icon_4a5fcc535cd48b590d28558f0a77efbe);
#
#
#         var popup_942d6d615dca5e624deac676623f2b2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_efcde92e841ebef24760288ecff13348 = $(`&lt;div id=&quot;html_efcde92e841ebef24760288ecff13348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_942d6d615dca5e624deac676623f2b2e.setContent(html_efcde92e841ebef24760288ecff13348);
#
#
#         marker_12161f4392e20bf821f0f66846ad670c.bindPopup(popup_942d6d615dca5e624deac676623f2b2e)
#         ;
#
#
#
#
#             var marker_1706309bdc98cbdf492a122f340e2983 = L.marker(
#                 [40.707142, -74.004987],
#                 {}
#             ).addTo(map_6c1fb316651803fd61f38d323cefe0d6);
#
#
#             var icon_f950e53244192e445418344683a6ff06 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1706309bdc98cbdf492a122f340e2983.setIcon(icon_f950e53244192e445418344683a6ff06);
#
#
#         var popup_c826e0cb8461ba564a01d1cb7042e2a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7cc9e01cf99968e341768f45fb98b411 = $(`&lt;div id=&quot;html_7cc9e01cf99968e341768f45fb98b411&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_c826e0cb8461ba564a01d1cb7042e2a5.setContent(html_7cc9e01cf99968e341768f45fb98b411);
#
#
#         marker_1706309bdc98cbdf492a122f340e2983.bindPopup(popup_c826e0cb8461ba564a01d1cb7042e2a5)
#         ;
#
#
#
#
#             var marker_4d718e57b3f65f18a5e6446d2e8e8b05 = L.marker(
#                 [40.708411, -74.007404],
#                 {}
#             ).addTo(map_6c1fb316651803fd61f38d323cefe0d6);
#
#
#             var icon_0d84f9a37e542ed0c8ed4f6dd04af314 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4d718e57b3f65f18a5e6446d2e8e8b05.setIcon(icon_0d84f9a37e542ed0c8ed4f6dd04af314);
#
#
#         var popup_d94b8ed54d3aad6f1541991c1453addc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_42c4005ed6c969719f957a17cecdadce = $(`&lt;div id=&quot;html_42c4005ed6c969719f957a17cecdadce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_d94b8ed54d3aad6f1541991c1453addc.setContent(html_42c4005ed6c969719f957a17cecdadce);
#
#
#         marker_4d718e57b3f65f18a5e6446d2e8e8b05.bindPopup(popup_d94b8ed54d3aad6f1541991c1453addc)
#         ;
#
#
#
#
#             var marker_ec915391b5e8e39aa459c4119c8366b9 = L.marker(
#                 [40.711644, -74.006667],
#                 {}
#             ).addTo(map_6c1fb316651803fd61f38d323cefe0d6);
#
#
#             var icon_886705b62206b9a7e1a48d17e639f081 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ec915391b5e8e39aa459c4119c8366b9.setIcon(icon_886705b62206b9a7e1a48d1

# %% [markdown]
# **3. Compute number of stores located in a given radius**

# %%
#All stores at a distance greater/less than x kms
df[df['Distance'] > 10]
# Out:
#            lat        lng      store  \
# 227  40.841350 -73.939822  Starbucks
# 228  40.841723 -73.941375  Starbucks
# 229  40.851000 -73.938421  Starbucks
# 230  40.865721 -73.927287  Starbucks
# 273  40.835319 -73.944335  McDonalds
# 277  40.842594 -73.938972  McDonalds
# 280  40.850094 -73.936035  McDonalds
# 286  40.865080 -73.927202  McDonalds
# 287  40.867396 -73.921301  McDonalds
#
#                                           address               Coordinate  \
# 227             4001 Broadway, New York, NY 10032   (40.84135, -73.939822)
# 228  177 Fort Washington Ave , New York, NY 10032  (40.841723, -73.941375)
# 229            803 W 181st St, New York, NY 10033     (40.851, -73.938421)
# 230             4761 Broadway, New York, NY 10040  (40.865721, -73.927287)
# 273                                 3809 BROADWAY  (40.835319, -73.944335)
# 277                                 4040 BROADWAY  (40.842594, -73.938972)
# 280                                 4259 BROADWAY  (40.850094, -73.936035)
# 286                                208 DYCKMAN ST   (40.86508, -73.927202)
# 287                         608 WEST 207TH STREET  (40.867396, -73.921301)
#
#       Distance
# 227  11.001594
# 228  10.995612
# 229  12.050055
# 230  13.906793
# 273  10.241912
# 277  11.156082
# 280  12.023104
# 286  13.842721
# 287  14.264323

# %% [markdown]
# **4. Compute the closest and farthest stores from Empire State Building**

# %%
df_farthest = df.iloc[df.groupby('store')['Distance'].agg(pd.Series.idxmax)]
df_closest = df.iloc[df.groupby('store')['Distance'].agg(pd.Series.idxmin)]
df_new = pd.concat([df_farthest, df_closest])

# %%
df_new
# Out:
#            lat        lng      store                               address  \
# 287  40.867396 -73.921301  McDonalds                 608 WEST 207TH STREET
# 230  40.865721 -73.927287  Starbucks     4761 Broadway, New York, NY 10040
# 256  40.750816 -73.986819  McDonalds                           972 6TH AVE
# 110  40.748660 -73.985614  Starbucks  350 Fifth Avenue, New York, NY 10118
#
#                   Coordinate   Distance
# 287  (40.867396, -73.921301)  14.264323
# 230  (40.865721, -73.927287)  13.906793
# 256  (40.750816, -73.986819)   0.290966
# 110   (40.74866, -73.985614)   0.037057

# %%
#Empire State Building coordinates
m = folium.Map(location=[40.748488, -73.985238], zoom_start= 10)

for i, rown in df_new.iterrows():
  lat = df_new.at[i, 'lat']
  lng = df_new.at[i, 'lng']
  store = df_new.at[i, 'store']

  if store == 'McDonalds':
    color = 'blue'
  else:
    color = 'green'

  folium.Marker(location=[lat,lng], popup=store, icon= folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a31f7b16da3bc93bde880bdaeea0017e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a31f7b16da3bc93bde880bdaeea0017e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a31f7b16da3bc93bde880bdaeea0017e = L.map(
#                 &quot;map_a31f7b16da3bc93bde880bdaeea0017e&quot;,
#                 {
#                     center: [40.748488, -73.985238],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cce2fbcb8a9b19de7221ea7b606f2da1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a31f7b16da3bc93bde880bdaeea0017e);
#
#
#             var marker_55d1a73f19bc6db954359b090fb159b7 = L.marker(
#                 [40.867396, -73.921301],
#                 {}
#             ).addTo(map_a31f7b16da3bc93bde880bdaeea0017e);
#
#
#             var icon_928368aa5cb17f1cbab22f496f527386 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_55d1a73f19bc6db954359b090fb159b7.setIcon(icon_928368aa5cb17f1cbab22f496f527386);
#
#
#         var popup_c95a9ae08ce8cdd91f1879d2ee9712ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4b67f9c7f673626604b0551c1f88f3c5 = $(`&lt;div id=&quot;html_4b67f9c7f673626604b0551c1f88f3c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#             popup_c95a9ae08ce8cdd91f1879d2ee9712ba.setContent(html_4b67f9c7f673626604b0551c1f88f3c5);
#
#
#         marker_55d1a73f19bc6db954359b090fb159b7.bindPopup(popup_c95a9ae08ce8cdd91f1879d2ee9712ba)
#         ;
#
#
#
#
#             var marker_3c47849f0ae215ccb69a80931338b53b = L.marker(
#                 [40.865721, -73.927287],
#                 {}
#             ).addTo(map_a31f7b16da3bc93bde880bdaeea0017e);
#
#
#             var icon_b2f12a5646f13de285b45efbdcdcc86d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c47849f0ae215ccb69a80931338b53b.setIcon(icon_b2f12a5646f13de285b45efbdcdcc86d);
#
#
#         var popup_a575bfa6f91a7167cf8aa5f1c4f73a78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cfc7c093128da165c2e0e718c165646e = $(`&lt;div id=&quot;html_cfc7c093128da165c2e0e718c165646e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Starbucks&lt;/div&gt;`)[0];
#             popup_a575bfa6f91a7167cf8aa5f1c4f73a78.setContent(html_cfc7c093128da165c2e0e718c165646e);
#
#
#         marker_3c47849f0ae215ccb69a80931338b53b.bindPopup(popup_a575bfa6f91a7167cf8aa5f1c4f73a78)
#         ;
#
#
#
#
#             var marker_c4b011d76d20a191a284fdd815514fa7 = L.marker(
#                 [40.750816, -73.986819],
#                 {}
#             ).addTo(map_a31f7b16da3bc93bde880bdaeea0017e);
#
#
#             var icon_7acd934dda10843179b771a00c0a2564 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c4b011d76d20a191a284fdd815514fa7.setIcon(icon_7acd934dda10843179b771a00c0a2564);
#
#
#         var popup_4b58d9aed7580f7db38c2381e2f0658d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1ae823601de2c545aea3779ff6ea2423 = $(`&lt;div id=&quot;html_1ae823601de2c545aea3779ff6ea2423&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonalds&lt;/div&gt;`)[0];
#             popup_4b58d9aed7580f7db38c2381e2f0658d.setContent(html_1ae823601de2c545aea3779ff6ea2423);
#
#
#         marker_c4b011d76d20a191a284fdd815514fa7.bindPopup(popup_4b58d9aed7580f7db38c2381e2f0658d)
#         ;
#
#
#
#
#             var marker_b5e4b299872bb0bbb1b22ded928c4c11 = L.marker(
#                 [40.74866, -73.985614],
#                 {}
#             ).addTo(map_a31f7b16da3bc93bde880bdaeea0017e);
#
#
#             var icon_815d661a513d63d67bbe31a84a03ba86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b5e4b299872bb0bbb1b22ded928c4c11.setIcon(icon_815d661a513d63d67bbe31a
